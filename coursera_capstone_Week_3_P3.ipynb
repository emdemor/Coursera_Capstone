# %% [markdown]
# # Applied Data Science Capstone
# *by IBM*

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Using `pandas.read_html` to get a dataframe of the postal code of each neighborhood along with the borough name and neighborhood name

# %%
df_codes = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]

# Only process the cells that have an assigned borough.
# Ignore cells with a borough that is Not assigned.
df_codes = df_codes[df_codes['Borough'] != 'Not assigned'].reset_index(drop=True)

# If a cell has a borough but a Not assigned  neighborhood,
# then the neighborhood will be the same as the borough.
df_codes['Neighbourhood'] = df_codes.apply(
    lambda x: x['Neighbourhood'] if x['Neighbourhood']!='Not assigned' else x['Borough'],axis=1)

# In order to utilize the Foursquare location data, we need
# to get the latitude and the longitude coordinates of each
# neighborhood.
df_geospatial = pd.read_csv('https://cocl.us/Geospatial_data')

# Joining datasets
df = df_codes.merge(df_geospatial,on="Postal Code",how="left")

# %%
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %% [markdown]
# In order to utilize the Foursquare location data, we need to get the latitude and the longitude coordinates of each neighborhood.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium

# %%
CLIENT_ID = 'BELQR33E4XOD32YRUYPSXUVVVR3GTWECQU2TXT1IT2CS10DG' # your Foursquare ID
CLIENT_SECRET = '3CCUNF3DMCFDUTCTIBLUYA0JWVXANW2EQ0R0GV4L5X2UKDFF' # your Foursquare Secret
ACCESS_TOKEN = '3DAFXVUZH2QSV4ARG42A5EATNKI1PODQNMAKUZMI31XZWE25' # your FourSquare Access Token
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: BELQR33E4XOD32YRUYPSXUVVVR3GTWECQU2TXT1IT2CS10DG
# CLIENT_SECRET:3CCUNF3DMCFDUTCTIBLUYA0JWVXANW2EQ0R0GV4L5X2UKDFF

# %%
df.iloc[0]
# Out:
# Postal Code             M3A
# Borough          North York
# Neighbourhood     Parkwoods
# Latitude            43.7533
# Longitude          -79.3297
# Name: 0, dtype: object

# %%
import requests

LIMIT = 100
radius = 500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    43.7533, 
    -79.3297,
    radius, 
    LIMIT)

results = requests.get(url).json()

# %%
df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %%
def get_nearby_venues(
    postal_code,
    latitude,
    longitude,
    radius = 500,
    limit = 100):
            
    # create the API request URL
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        latitude, 
        longitude, 
        radius, 
        limit)

    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    return [{
        'postal_code': postal_code,
        'name': result['venue']['name'],
        'categories': [cat['name'] for cat in result['venue']['categories']],
#         'categories_full': result['venue']['categories']
        
    } for result in results]

# %%
results = get_nearby_venues('M3A', 43.7533, -79.3297, radius=500)

# %%
from tqdm import tqdm

list_venues = []
for index, row in tqdm(df.iterrows(),total = len(df)):
    results = get_nearby_venues(
        str(row['Postal Code']), 
        row['Latitude'],
        row['Longitude'],
    )
    
    categories = []
    for result in results:
        categories += result['categories']
    
    list_venues.append({
        'postal_code': row['Postal Code'],
        'categories': pd.Series(categories,name = 'categories').value_counts().to_dict()
    })
# Out:
#   5%|▍         | 5/103 [00:03<00:59,  1.65it/s]/home/eduardo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# 100%|██████████| 103/103 [01:26<00:00,  1.19it/s]

# %%
list_venues
# Out:
# [{'postal_code': 'M3A',
#   'categories': {'Park': 1, 'Pool': 1, 'Food & Drink Shop': 1}},
#  {'postal_code': 'M4A',
#   'categories': {'Portuguese Restaurant': 1,
#    'Intersection': 1,
#    'Hockey Arena': 1,
#    'Pizza Place': 1,
#    'Coffee Shop': 1}},
#  {'postal_code': 'M5A',
#   'categories': {'Coffee Shop': 8,
#    'Pub': 3,
#    'Bakery': 3,
#    'Park': 3,
#    'Theater': 2,
#    'Restaurant': 2,
#    'Breakfast Spot': 2,
#    'Café': 2,
#    'Art Gallery': 1,
#    'Bank': 1,
#    'Antique Shop': 1,
#    'Historic Site': 1,
#    'Asian Restaurant': 1,
#    'Spa': 1,
#    'Chocolate Shop': 1,
#    'Mexican Restaurant': 1,
#    'Performing Arts Venue': 1,
#    'Electronics Store': 1,
#    'Farmers Market': 1,
#    'Distribution Center': 1,
#    'Beer Store': 1,
#    'Event Space': 1,
#    'French Restaurant': 1,
#    'Gym / Fitness Center': 1,
#    'Yoga Studio': 1,
#    'Dessert Shop': 1,
#    'Wine Shop': 1,
#    'Cosmetics Shop': 1,
#    'Shoe Store': 1}},
#  {'postal_code': 'M6A',
#   'categories': {'Clothing Store': 3,
#    'Furniture / Home Store': 2,
#    'Arts & Crafts Store': 1,
#    'Coffee Shop': 1,
#    'Accessories Store': 1,
#    'Miscellaneous Shop': 1,
#    'Event Space': 1,
#    'Vietnamese Restaurant': 1,
#    'Boutique': 1}},
#  {'postal_code': 'M7A',
#   'categories': {'Coffee Shop': 8,
#    'Sushi Restaurant': 2,
#    'Portuguese Restaurant': 1,
#    'Park': 1,
#    'Fried Chicken Joint': 1,
#    'Burrito Place': 1,
#    'Diner': 1,
#    'Yoga Studio': 1,
#    'Creperie': 1,
#    'Mexican Restaurant': 1,
#    'Sandwich Place': 1,
#    'Art Gallery': 1,
#    'Distribution Center': 1,
#    'College Auditorium': 1,
#    'General Entertainment': 1,
#    'Café': 1,
#    'College Cafeteria': 1,
#    'Beer Bar': 1,
#    'Japanese Restaurant': 1,
#    'Music Venue': 1,
#    'Italian Restaurant': 1,
#    'Smoothie Shop': 1,
#    'Theater': 1,
#    'Bar': 1,
#    'Gym': 1,
#    'Bank': 1}},
#  {'postal_code': 'M9A', 'categories': {}},
#  {'postal_code': 'M1B',
#   'categories': {'Fast Food Restaurant': 1, 'Print Shop': 1}},
#  {'postal_code': 'M3B',
#   'categories': {'Café': 1,
#    'Gym': 1,
#    'Caribbean Restaurant': 1,
#    'Japanese Restaurant': 1}},
#  {'postal_code': 'M4B',
#   'categories': {'Pizza Place': 2,
#    'Flea Market': 1,
#    'Intersection': 1,
#    'Pharmacy': 1,
#    'Gym / Fitness Center': 1,
#    'Gastropub': 1,
#    'Bank': 1,
#    'Athletics & Sports': 1}},
#  {'postal_code': 'M5B',
#   'categories': {'Clothing Store': 9,
#    'Coffee Shop': 8,
#    'Bubble Tea Shop': 3,
#    'Japanese Restaurant': 3,
#    'Café': 3,
#    'Cosmetics Shop': 3,
#    'Middle Eastern Restaurant': 3,
#    'Fast Food Restaurant': 2,
#    'Movie Theater': 2,
#    'Diner': 2,
#    'Electronics Store': 2,
#    'Pizza Place': 2,
#    'Italian Restaurant': 2,
#    'Lingerie Store': 2,
#    'Theater': 2,
#    'Hotel': 2,
#    'Ramen Restaurant': 2,
#    'Pharmacy': 1,
#    'Chinese Restaurant': 1,
#    'Poutine Place': 1,
#    'Shoe Store': 1,
#    'College Rec Center': 1,
#    'Music Venue': 1,
#    'Dessert Shop': 1,
#    'Plaza': 1,
#    'Spa': 1,
#    'Comic Shop': 1,
#    'Mexican Restaurant': 1,
#    'New American Restaurant': 1,
#    'Smoke Shop': 1,
#    'Lounge': 1,
#    'Restaurant': 1,
#    'Tea Room': 1,
#    'Burrito Place': 1,
#    'Bookstore': 1,
#    'Bakery': 1,
#    'Sporting Goods Shop': 1,
#    'Gym': 1,
#    'Ice Cream Shop': 1,
#    'Hookah Bar': 1,
#    'Modern European Restaurant': 1,
#    'Furniture / Home Store': 1,
#    'Gym / Fitness Center': 1,
#    'Miscellaneous Shop': 1,
#    'Burger Joint': 1,
#    'Steakhouse': 1,
#    'Ethiopian Restaurant': 1,
#    'Art Gallery': 1,
#    'Sandwich Place': 1,
#    'Vietnamese Restaurant': 1,
#    'Office': 1,
#    'Video Game Store': 1,
#    'Wine Bar': 1,
#    'Thai Restaurant': 1,
#    'Park': 1,
#    'Other Great Outdoors': 1,
#    'Seafood Restaurant': 1,
#    'Tanning Salon': 1,
#    'Shopping Mall': 1,
#    'Department Store': 1,
#    'Lake': 1,
#    'Gastropub': 1,
#    'Juice Bar': 1,
#    'Distribution Center': 1,
#    'Bank': 1}},
#  {'postal_code': 'M6B',
#   'categories': {'Metro Station': 1,
#    'Japanese Restaurant': 1,
#    'Pizza Place': 1,
#    'Bakery': 1,
#    'Pub': 1}},
#  {'postal_code': 'M9B', 'categories': {'Bakery': 1}},
#  {'postal_code': 'M1C',
#   'categories': {'Bar': 1,
#    'Construction & Landscaping': 1,
#    'Moving Target': 1}},
#  {'postal_code': 'M3C',
#   'categories': {'Coffee Shop': 2,
#    'Beer Store': 2,
#    'Gym': 2,
#    'Restaurant': 2,
#    'Asian Restaurant': 1,
#    'Bike Shop': 1,
#    'Sandwich Place': 1,
#    'Discount Store': 1,
#    'Dim Sum Restaurant': 1,
#    'Sporting Goods Shop': 1,
#    'Italian Restaurant': 1,
#    'Chinese Restaurant': 1,
#    'Japanese Restaurant': 1,
#    'Clothing Store': 1,
#    'Art Gallery': 1,
#    'Supermarket': 1}},
#  {'postal_code': 'M4C',
#   'categories': {'Video Store': 1,
#    'Intersection': 1,
#    'Beer Store': 1,
#    'Curling Ice': 1,
#    'Skating Rink': 1,
#    'Bus Stop': 1,
#    'Park': 1,
#    'Spa': 1}},
#  {'postal_code': 'M5C',
#   'categories': {'Coffee Shop': 5,
#    'Café': 4,
#    'Gastropub': 3,
#    'Cocktail Bar': 3,
#    'American Restaurant': 3,
#    'Moroccan Restaurant': 2,
#    'Gym': 2,
#    'Seafood Restaurant': 2,
#    'Creperie': 2,
#    'Department Store': 2,
#    'Farmers Market': 2,
#    'Bakery': 2,
#    'Italian Restaurant': 2,
#    'Lingerie Store': 2,
#    'Cosmetics Shop': 2,
#    'Clothing Store': 2,
#    'Restaurant': 2,
#    'Hotel': 2,
#    'Pharmacy': 1,
#    'Irish Pub': 1,
#    'Bookstore': 1,
#    'Burrito Place': 1,
#    'Bistro': 1,
#    'Middle Eastern Restaurant': 1,
#    'Asian Restaurant': 1,
#    'Comfort Food Restaurant': 1,
#    'Theater': 1,
#    'Salon / Barbershop': 1,
#    'Diner': 1,
#    'New American Restaurant': 1,
#    'Convenience Store': 1,
#    'Belgian Restaurant': 1,
#    'German Restaurant': 1,
#    'French Restaurant': 1,
#    'Japanese Restaurant': 1,
#    'Tailor Shop': 1,
#    'Grocery Store': 1,
#    'Performing Arts Venue': 1,
#    'Food Truck': 1,
#    'Electronics Store': 1,
#    'Fish Market': 1,
#    'Jazz Club': 1,
#    'Beer Bar': 1,
#    'Wine Bar': 1,
#    'Art Gallery': 1,
#    'Fountain': 1,
#    'BBQ Joint': 1,
#    'Thai Restaurant': 1,
#    'Vegetarian / Vegan Restaurant': 1,
#    'Breakfast Spot': 1,
#    'Pizza Place': 1,
#    'Park': 1}},
#  {'postal_code': 'M6C',
#   'categories': {'Playground': 1, 'Hockey Arena': 1, 'Field': 1, 'Trail': 1}},
#  {'postal_code': 'M9C',
#   'categories': {'Café': 1,
#    'Pet Store': 1,
#    'Liquor Store': 1,
#    'Beer Store': 1,
#    'Coffee Shop': 1,
#    'Pharmacy': 1,
#    'Pizza Place': 1,
#    'Convenience Store': 1}},
#  {'postal_code': 'M1E',
#   'categories': {'Intersection': 1,
#    'Electronics Store': 1,
#    'Medical Center': 1,
#    'Breakfast Spot': 1,
#    'Mexican Restaurant': 1,
#    'Restaurant': 1,
#    'Rental Car Location': 1,
#    'Bank': 1}},
#  {'postal_code': 'M4E',
#   'categories': {'Health Food Store': 1,
#    'Neighborhood': 1,
#    'Trail': 1,
#    'Pub': 1}},
#  {'postal_code': 'M5E',
#   'categories': {'Coffee Shop': 5,
#    'Cocktail Bar': 3,
#    'Farmers Market': 2,
#    'Bakery': 2,
#    'Restaurant': 2,
#    'Seafood Restaurant': 2,
#    'Beer Bar': 2,
#    'Cheese Shop': 2,
#    'Vegetarian / Vegan Restaurant': 1,
#    'Hotel': 1,
#    'Art Gallery': 1,
#    'Clothing Store': 1,
#    'Steakhouse': 1,
#    'Fountain': 1,
#    'Juice Bar': 1,
#    'Creperie': 1,
#    'Nightclub': 1,
#    'Tailor Shop': 1,
#    'Thai Restaurant': 1,
#    'Diner': 1,
#    'Bistro': 1,
#    'Basketball Stadium': 1,
#    'Breakfast Spot': 1,
#    'Park': 1,
#    'Bagel Shop': 1,
#    'Comfort Food Restaurant': 1,
#    'Museum': 1,
#    'Sporting Goods Shop': 1,
#    'French Restaurant': 1,
#    'Beach': 1,
#    'Fish Market': 1,
#    'Sushi Restaurant': 1,
#    'Liquor Store': 1,
#    'Concert Hall': 1,
#    'Eastern European Restaurant': 1,
#    'Japanese Restaurant': 1,
#    'Department Store': 1,
#    'Greek Restaurant': 1,
#    'Jazz Club': 1,
#    'Pharmacy': 1,
#    'Café': 1,
#    'Gourmet Shop': 1,
#    'Grocery Store': 1,
#    'Irish Pub': 1}},
#  {'postal_code': 'M6E',
#   'categories': {'Park': 2, "Women's Store": 1, 'Bar': 1}},
#  {'postal_code': 'M1G',
#   'categories': {'Coffee Shop': 2, 'Korean BBQ Restaurant': 1, 'Pharmacy': 1}},
#  {'postal_code': 'M4G',
#   'categories': {'Coffee Shop': 3,
#    'Sporting Goods Shop': 3,
#    'Furniture / Home Store': 2,
#    'Bank': 2,
#    'Burger Joint': 2,
#    'Smoothie Shop': 1,
#    'Breakfast Spot': 1,
#    'Fish & Chips Shop': 1,
#    'Mexican Restaurant': 1,
#    'Sandwich Place': 1,
#    'Dessert Shop': 1,
#    'Restaurant': 1,
#    'Pet Store': 1,
#    'Beer Store': 1,
#    'Bagel Shop': 1,
#    'Liquor Store': 1,
#    'Sports Bar': 1,
#    'Brewery': 1,
#    'Shopping Mall': 1,
#    'Sushi Restaurant': 1,
#    'Electronics Store': 1,
#    'Department Store': 1,
#    'Bike Shop': 1,
#    'Grocery Store': 1,
#    'Supermarket': 1}},
#  {'postal_code': 'M5G',
#   'categories': {'Coffee Shop': 11,
#    'Café': 3,
#    'Sandwich Place': 3,
#    'Italian Restaurant': 3,
#    'Bubble Tea Shop': 2,
#    'Salad Place': 2,
#    'Burger Joint': 2,
#    'Thai Restaurant': 1,
#    'Tea Room': 1,
#    'Indian Restaurant': 1,
#    'Ramen Restaurant': 1,
#    'Office': 1,
#    'Korean Restaurant': 1,
#    'Spa': 1,
#    'Modern European Restaurant': 1,
#    'Discount Store': 1,
#    'Pizza Place': 1,
#    'Comic Shop': 1,
#    'Sushi Restaurant': 1,
#    'Falafel Restaurant': 1,
#    'Chinese Restaurant': 1,
#    'Park': 1,
#    'Furniture / Home Store': 1,
#    'Portuguese Restaurant': 1,
#    'Middle Eastern Restaurant': 1,
#    'Business Service': 1,
#    'Donut Shop': 1,
#    'Bar': 1,
#    'Diner': 1,
#    'Department Store': 1,
#    'Vegetarian / Vegan Restaurant': 1,
#    'Gastropub': 1,
#    'Juice Bar': 1,
#    'Wine Bar': 1,
#    'Poke Place': 1,
#    'Ice Cream Shop': 1,
#    'Yoga Studio': 1,
#    'Art Museum': 1,
#    'Gym / Fitness Center': 1,
#    'French Restaurant': 1,
#    'Miscellaneous Shop': 1,
#    'Japanese Restaurant': 1,
#    'Bank': 1}},
#  {'postal_code': 'M6G',
#   'categories': {'Grocery Store': 4,
#    'Café': 3,
#    'Park': 2,
#    'Athletics & Sports': 1,
#    'Nightclub': 1,
#    'Coffee Shop': 1,
#    'Candy Store': 1,
#    'Italian Restaurant': 1,
#    'Restaurant': 1,
#    'Baby Store': 1,
#    'Bank': 1}},
#  {'postal_code': 'M1H',
#   'categories': {'Athletics & Sports': 1,
#    'Hakka Restaurant': 1,
#    'Thai Restaurant': 1,
#    'Fried Chicken Joint': 1,
#    'Gas Station': 1,
#    'Caribbean Restaurant': 1,
#    'Bakery': 1,
#    'Bank': 1}},
#  {'postal_code': 'M2H',
#   'categories': {'Fast Food Restaurant': 1,
#    'Mediterranean Restaurant': 1,
#    'Golf Course': 1,
#    'Dog Run': 1,
#    'Pool': 1}},
#  {'postal_code': 'M3H',
#   'categories': {'Bank': 2,
#    'Coffee Shop': 2,
#    'Middle Eastern Restaurant': 1,
#    'Ice Cream Shop': 1,
#    'Restaurant': 1,
#    'Fried Chicken Joint': 1,
#    'Diner': 1,
#    'Deli / Bodega': 1,
#    'Gift Shop': 1,
#    'Health Food Store': 1,
#    'Pizza Place': 1,
#    'Pharmacy': 1,
#    'Gas Station': 1,
#    'Park': 1,
#    'Shopping Mall': 1,
#    'Sushi Restaurant': 1,
#    'Mobile Phone Shop': 1,
#    'Bridal Shop': 1,
#    'Sandwich Place': 1,
#    'Supermarket': 1}},
#  {'postal_code': 'M4H',
#   'categories': {'Sandwich Place': 2,
#    'Indian Restaurant': 2,
#    'Intersection': 1,
#    'Liquor Store': 1,
#    'Bank': 1,
#    'Burger Joint': 1,
#    'Warehouse Store': 1,
#    'Yoga Studio': 1,
#    'Restaurant': 1,
#    'Fast Food Restaurant': 1,
#    'Pharmacy': 1,
#    'Middle Eastern Restaurant': 1,
#    'Pizza Place': 1,
#    'Park': 1,
#    'Gas Station': 1,
#    'Gym': 1,
#    'Coffee Shop': 1,
#    'Grocery Store': 1,
#    'Supermarket': 1}},
#  {'postal_code': 'M5H',
#   'categories': {'Coffee Shop': 9,
#    'Café': 5,
#    'Restaurant': 4,
#    'Deli / Bodega': 3,
#    'Gym': 3,
#    'Thai Restaurant': 3,
#    'Clothing Store': 3,
#    'Bakery': 3,
#    'Cosmetics Shop': 2,
#    'Sushi Restaurant': 2,
#    'Bookstore': 2,
#    'Steakhouse': 2,
#    'American Restaurant': 2,
#    'Salad Place': 2,
#    'Concert Hall': 2,
#    'Hotel': 2,
#    'Pizza Place': 2,
#    'Burrito Place': 2,
#    'Art Museum': 1,
#    'Plaza': 1,
#    'Event Space': 1,
#    'Poke Place': 1,
#    'Colombian Restaurant': 1,
#    'New American Restaurant': 1,
#    'Salon / Barbershop': 1,
#    'Burger Joint': 1,
#    'Soup Place': 1,
#    'Fast Food Restaurant': 1,
#    'Building': 1,
#    'Asian Restaurant': 1,
#    'Lounge': 1,
#    'Speakeasy': 1,
#    'Gift Shop': 1,
#    'Nightclub': 1,
#    'Bar': 1,
#    'Latin American Restaurant': 1,
#    'Smoke Shop': 1,
#    'Modern European Restaurant': 1,
#    'Food Court': 1,
#    'Theater': 1,
#    'Brazilian Restaurant': 1,
#    'Gym / Fitness Center': 1,
#    'Jazz Club': 1,
#    'Japanese Restaurant': 1,
#    'Neighborhood': 1,
#    'Art Gallery': 1,
#    'Juice Bar': 1,
#    'Sandwich Place': 1,
#    'Vegetarian / Vegan Restaurant': 1,
#    'Breakfast Spot': 1,
#    'Park': 1,
#    'Seafood Restaurant': 1,
#    'Noodle House': 1,
#    'Mediterranean Restaurant': 1,
#    'Gluten-free Restaurant': 1,
#    'Gastropub': 1,
#    'Cupcake Shop': 1}},
#  {'postal_code': 'M6H',
#   'categories': {'Pharmacy': 2,
#    'Bakery': 2,
#    'Café': 1,
#    'Middle Eastern Restaurant': 1,
#    'Grocery Store': 1,
#    'Coffee Shop': 1,
#    'Brewery': 1,
#    'Wine Shop': 1,
#    'Liquor Store': 1,
#    'Music Venue': 1,
#    'Pool': 1,
#    'Bar': 1,
#    'Park': 1,
#    'Bank': 1,
#    'Supermarket': 1}},
#  {'postal_code': 'M1J', 'categories': {'Playground': 1}},
#  {'postal_code': 'M2J',
#   'categories': {'Clothing Store': 9,
#    'Coffee Shop': 5,
#    'Fast Food Restaurant': 4,
#    'Restaurant': 3,
#    'Japanese Restaurant': 2,
#    'Mobile Phone Shop': 2,
#    'Jewelry Store': 2,
#    'Juice Bar': 2,
#    'Food Court': 2,
#    'Bakery': 2,
#    'Bank': 2,
#    'Burrito Place': 1,
#    'Frozen Yogurt Shop': 1,
#    "Men's Store": 1,
#    'Ice Cream Shop': 1,
#    'Asian Restaurant': 1,
#    'Boutique': 1,
#    'Chocolate Shop': 1,
#    'Convenience Store': 1,
#    'Salon / Barbershop': 1,
#    'Shopping Mall': 1,
#    'Electronics Store': 1,
#    'Deli / Bodega': 1,
#    'Sporting Goods Shop': 1,
#    'Cosmetics Shop': 1,
#    'Tea Room': 1,
#    'Department Store': 1,
#    'Spa': 1,
#    'Baseball Field': 1,
#    'Video Game Store': 1,
#    'Theater': 1,
#    'Sandwich Place': 1,
#    'Intersection': 1,
#    'Liquor Store': 1,
#    'Bar': 1,
#    'Toy / Game Store': 1,
#    'Burger Joint': 1,
#    'American Restaurant': 1,
#    'Pharmacy': 1,
#    'Movie Theater': 1}},
#  {'postal_code': 'M3J',
#   'categories': {'Bar': 1,
#    'Falafel Restaurant': 1,
#    'Caribbean Restaurant': 1,
#    'Massage Studio': 1,
#    'Coffee Shop': 1}},
#  {'postal_code': 'M4J',
#   'categories': {'Park': 2, 'Intersection': 1, 'Convenience Store': 1}},
#  {'postal_code': 'M5J',
#   'categories': {'Coffee Shop': 12,
#    'Aquarium': 5,
#    'Hotel': 4,
#    'Café': 4,
#    'Italian Restaurant': 3,
#    'Scenic Lookout': 3,
#    'Restaurant': 3,
#    'Fried Chicken Joint': 3,
#    'Brewery': 3,
#    'Baseball Stadium': 2,
#    'Music Venue': 2,
#    'Plaza': 2,
#    'Bar': 2,
#    'Park': 2,
#    'Pizza Place': 2,
#    'Sporting Goods Shop': 2,
#    'History Museum': 2,
#    'Bakery': 2,
#    'Bank': 2,
#    'Wine Bar': 1,
#    'Lounge': 1,
#    'Sports Bar': 1,
#    'Ice Cream Shop': 1,
#    'Sushi Restaurant': 1,
#    'Roof Deck': 1,
#    'Tea Room': 1,
#    'Lake': 1,
#    'Dance Studio': 1,
#    'Bistro': 1,
#    'Salad Place': 1,
#    'Dessert Shop': 1,
#    'New American Restaurant': 1,
#    'Department Store': 1,
#    'Juice Bar': 1,
#    'IT Services': 1,
#    'Food Court': 1,
#    'Theater': 1,
#    'Deli / Bodega': 1,
#    'Basketball Stadium': 1,
#    'Japanese Restaurant': 1,
#    'Beer Bar': 1,
#    'Neighborhood': 1,
#    'Hotel Bar': 1,
#    'Skating Rink': 1,
#    'Steakhouse': 1,
#    'Art Gallery': 1,
#    'Sandwich Place': 1,
#    'Office': 1,
#    'Indian Restaurant': 1,
#    'Chinese Restaurant': 1,
#    'Vegetarian / Vegan Restaurant': 1,
#    'Monument / Landmark': 1,
#    'Train Station': 1,
#    'Seafood Restaurant': 1,
#    'Discount Store': 1,
#    'Bubble Tea Shop': 1,
#    'Indie Movie Theater': 1,
#    'Performing Arts Venue': 1,
#    'Supermarket': 1}},
#  {'postal_code': 'M6J',
#   'categories': {'Bar': 5,
#    'Restaurant': 2,
#    "Men's Store": 2,
#    'Vegetarian / Vegan Restaurant': 2,
#    'Café': 2,
#    'Asian Restaurant': 2,
#    'Theater': 1,
#    'Ice Cream Shop': 1,
#    'Brewery': 1,
#    'New American Restaurant': 1,
#    'Vietnamese Restaurant': 1,
#    'Portuguese Restaurant': 1,
#    'Beer Store': 1,
#    'Yoga Studio': 1,
#    'Diner': 1,
#    'Greek Restaurant': 1,
#    'Art Gallery': 1,
#    'Korean Restaurant': 1,
#    'Coffee Shop': 1,
#    'Record Shop': 1,
#    'Cuban Restaurant': 1,
#    'Cupcake Shop': 1,
#    'Cocktail Bar': 1,
#    'Park': 1,
#    'Japanese Restaurant': 1,
#    'Miscellaneous Shop': 1,
#    'French Restaurant': 1,
#    'Gift Shop': 1,
#    'Boutique': 1,
#    'Wine Bar': 1,
#    'Italian Restaurant': 1,
#    'Pizza Place': 1,
#    'Bakery': 1}},
#  {'postal_code': 'M1K',
#   'categories': {'Chinese Restaurant': 1,
#    'Hobby Shop': 1,
#    'Department Store': 1,
#    'Convenience Store': 1,
#    'Coffee Shop': 1}},
#  {'postal_code': 'M2K',
#   'categories': {'Café': 1,
#    'Japanese Restaurant': 1,
#    'Bank': 1,
#    'Chinese Restaurant': 1}},
#  {'postal_code': 'M3K', 'categories': {'Park': 1, 'Airport': 1}},
#  {'postal_code': 'M4K',
#   'categories': {'Greek Restaurant': 7,
#    'Coffee Shop': 4,
#    'Italian Restaurant': 3,
#    'Furniture / Home Store': 2,
#    'Restaurant': 2,
#    'Ice Cream Shop': 2,
#    'Bubble Tea Shop': 1,
#    'Fruit & Vegetable Store': 1,
#    'Trail': 1,
#    'Bakery': 1,
#    'Bookstore': 1,
#    'Tibetan Restaurant': 1,
#    'Frozen Yogurt Shop': 1,
#    'Yoga Studio': 1,
#    'Indian Restaurant': 1,
#    'Lounge': 1,
#    'Brewery': 1,
#    'Spa': 1,
#    'Pizza Place': 1,
#    'Grocery Store': 1,
#    'Café': 1,
#    'American Restaurant': 1,
#    'Caribbean Restaurant': 1,
#    'Dessert Shop': 1,
#    'Liquor Store': 1,
#    'Cosmetics Shop': 1,
#    'Juice Bar': 1,
#    'Pub': 1}},
#  {'postal_code': 'M5K',
#   'categories': {'Coffee Shop': 11,
#    'Hotel': 9,
#    'Café': 6,
#    'Italian Restaurant': 3,
#    'American Restaurant': 3,
#    'Seafood Restaurant': 3,
#    'Restaurant': 3,
#    'Salad Place': 3,
#    'Japanese Restaurant': 3,
#    'Sporting Goods Shop': 2,
#    'Asian Restaurant': 2,
#    'Concert Hall': 2,
#    'Steakhouse': 2,
#    'Breakfast Spot': 2,
#    'Beer Bar': 2,
#    'Gastropub': 2,
#    'Deli / Bodega': 2,
#    'Bakery': 2,
#    'Sushi Restaurant': 2,
#    'French Restaurant': 1,
#    'Bar': 1,
#    'Irish Pub': 1,
#    'Museum': 1,
#    'Gym': 1,
#    'General Entertainment': 1,
#    'Salon / Barbershop': 1,
#    'New American Restaurant': 1,
#    'Fast Food Restaurant': 1,
#    'Lounge': 1,
#    'Clothing Store': 1,
#    'Roof Deck': 1,
#    'Tea Room': 1,
#    'Speakeasy': 1,
#    'Garden': 1,
#    'Wine Bar': 1,
#    'Burrito Place': 1,
#    'Food Court': 1,
#    'Theater': 1,
#    'General Travel': 1,
#    'Gym / Fitness Center': 1,
#    'Plaza': 1,
#    'Shopping Mall': 1,
#    'Pizza Place': 1,
#    'Taco Place': 1,
#    'Sandwich Place': 1,
#    'Gluten-free Restaurant': 1,
#    'Chinese Restaurant': 1,
#    'Basketball Stadium': 1,
#    'Pub': 1,
#    'Train Station': 1,
#    'Tailor Shop': 1,
#    'Greek Restaurant': 1,
#    'IT Services': 1,
#    'Vegetarian / Vegan Restaurant': 1,
#    'Art Gallery': 1}},
#  {'postal_code': 'M6K',
#   'categories': {'Café': 3,
#    'Coffee Shop': 2,
#    'Breakfast Spot': 2,
#    'Nightclub': 1,
#    'Restaurant': 1,
#    'Burrito Place': 1,
#    'Bar': 1,
#    'Convenience Store': 1,
#    'Italian Restaurant': 1,
#    'Pet Store': 1,
#    'Intersection': 1,
#    'Furniture / Home Store': 1,
#    'Stadium': 1,
#    'Climbing Gym': 1,
#    'Gym': 1,
#    'Performing Arts Venue': 1,
#    'Grocery Store': 1,
#    'Bakery': 1}},
#  {'postal_code': 'M1L',
#   'categories': {'Bus Line': 2,
#    'Bakery': 2,
#    'Metro Station': 1,
#    'Intersection': 1,
#    'Soccer Field': 1,
#    'Ice Cream Shop': 1,
#    'Park': 1,
#    'Bus Station': 1}},
#  {'postal_code': 'M2L', 'categories': {}},
#  {'postal_code': 'M3L',
#   'categories': {'Grocery Store': 2,
#    'Shopping Mall': 1,
#    'Park': 1,
#    'Bank': 1}},
#  {'postal_code': 'M4L',
#   'categories': {'Fast Food Restaurant': 2,
#    'Movie Theater': 1,
#    'Italian Restaurant': 1,
#    'Steakhouse': 1,
#    'Park': 1,
#    'Fish & Chips Shop': 1,
#    'Sandwich Place': 1,
#    'Sushi Restaurant': 1,
#    'Food & Drink Shop': 1,
#    'Restaurant': 1,
#    'Gym': 1,
#    'Liquor Store': 1,
#    'Pet Store': 1,
#    'Pizza Place': 1,
#    'Brewery': 1,
#    'Ice Cream Shop': 1,
#    'Pub': 1}},
#  {'postal_code': 'M5L',
#   'categories': {'Coffee Shop': 12,
#    'Restaurant': 7,
#    'Hotel': 6,
#    'Café': 6,
#    'American Restaurant': 4,
#    'Gym': 4,
#    'Italian Restaurant': 4,
#    'Seafood Restaurant': 3,
#    'Deli / Bodega': 3,
#    'Japanese Restaurant': 3,
#    'Cocktail Bar': 3,
#    'Vegetarian / Vegan Restaurant': 2,
#    'Pizza Place': 2,
#    'Beer Bar': 2,
#    'Gastropub': 2,
#    'Thai Restaurant': 2,
#    'Bar': 1,
#    'French Restaurant': 1,
#    'Poke Place': 1,
#    'New American Restaurant': 1,
#    'Irish Pub': 1,
#    'Monument / Landmark': 1,
#    'Museum': 1,
#    'Salon / Barbershop': 1,
#    'Fast Food Restaurant': 1,
#    'Asian Restaurant': 1,
#    'Tea Room': 1,
#    'Shopping Mall': 1,
#    'Salad Place': 1,
#    'Bookstore': 1,
#    'Sporting Goods Shop': 1,
#    'Pub': 1,
#    'Wine Bar': 1,
#    'Gift Shop': 1,
#    'Food Truck': 1,
#    'Food Court': 1,
#    'Gym / Fitness Center': 1,
#    'Jazz Club': 1,
#    'Fried Chicken Joint': 1,
#    'Burger Joint': 1,
#    'Steakhouse': 1,
#    'Latin American Restaurant': 1,
#    'Gluten-free Restaurant': 1,
#    'Art Gallery': 1,
#    'Sandwich Place': 1,
#    'Fountain': 1,
#    'Creperie': 1,
#    'Breakfast Spot': 1,
#    'Park': 1,
#    'Tailor Shop': 1,
#    'Bakery': 1}},
#  {'postal_code': 'M6L',
#   'categories': {'Basketball Court': 1,
#    'Park': 1,
#    'Bakery': 1,
#    'Construction & Landscaping': 1}},
#  {'postal_code': 'M9L',
#   'categories': {'Intersection': 1, 'Furniture / Home Store': 1}},
#  {'postal_code': 'M1M', 'categories': {'American Restaurant': 1, 'Motel': 1}},
#  {'postal_code': 'M2M', 'categories': {'Park': 1}},
#  {'postal_code': 'M3M',
#   'categories': {'Baseball Field': 1, 'Food Truck': 1, 'Business Service': 1}},
#  {'postal_code': 'M4M',
#   'categories': {'Coffee Shop': 3,
#    'Bakery': 2,
#    'Café': 2,
#    'American Restaurant': 2,
#    'Brewery': 2,
#    'Gastropub': 2,
#    'Park': 1,
#    'Bookstore': 1,
#    'Thai Restaurant': 1,
#    'Ice Cream Shop': 1,
#    'Yoga Studio': 1,
#    'Coworking Space': 1,
#    'Bank': 1,
#    'Clothing Store': 1,
#    'Pet Store': 1,
#    'Convenience Store': 1,
#    'Diner': 1,
#    'Seafood Restaurant': 1,
#    'Comfort Food Restaurant': 1,
#    'Latin American Restaurant': 1,
#    'Pharmacy': 1,
#    'Middle Eastern Restaurant': 1,
#    'Food': 1,
#    'Neighborhood': 1,
#    'Bar': 1,
#    'Gym / Fitness Center': 1,
#    'Italian Restaurant': 1,
#    'Fish Market': 1,
#    'Gay Bar': 1,
#    'Stationery Store': 1,
#    'Cheese Shop': 1}},
#  {'postal_code': 'M5M',
#   'categories': {'Italian Restaurant': 2,
#    'Coffee Shop': 2,
#    'Sandwich Place': 2,
#    'Juice Bar': 2,
#    'Café': 1,
#    'American Restaurant': 1,
#    'Restaurant': 1,
#    'Toy / Game Store': 1,
#    'Hobby Shop': 1,
#    'Thai Restaurant': 1,
#    'Indian Restaurant': 1,
#    'Pizza Place': 1,
#    'Liquor Store': 1,
#    'Butcher': 1,
#    'Sushi Restaurant': 1,
#    'Comfort Food Restaurant': 1,
#    'Greek Restaurant': 1,
#    'Grocery Store': 1,
#    'Pharmacy': 1,
#    'Pub': 1}},
#  {'postal_code': 'M6M',
#   'categories': {'Fast Food Restaurant': 2,
#    'Sandwich Place': 1,
#    'Fried Chicken Joint': 1}},
#  {'postal_code': 'M9M', 'categories': {'Baseball Field': 1, 'Fabric Shop': 1}},
#  {'postal_code': 'M1N',
#   'categories': {'Café': 1,
#    'Skating Rink': 1,
#    'General Entertainment': 1,
#    'College Stadium': 1}},
#  {'postal_code': 'M2N',
#   'categories': {'Ramen Restaurant': 3,
#    'Sandwich Place': 2,
#    'Restaurant': 2,
#    'Shopping Mall': 2,
#    'Café': 2,
#    'Coffee Shop': 2,
#    'Pizza Place': 2,
#    'Bubble Tea Shop': 1,
#    'Arts & Crafts Store': 1,
#    'Lounge': 1,
#    'Pet Store': 1,
#    'Fast Food Restaurant': 1,
#    'Vietnamese Restaurant': 1,
#    'Discount Store': 1,
#    'Sushi Restaurant': 1,
#    'Grocery Store': 1,
#    'Electronics Store': 1,
#    'Movie Theater': 1,
#    'Middle Eastern Restaurant': 1,
#    'Steakhouse': 1,
#    'Plaza': 1,
#    'Japanese Restaurant': 1,
#    'Ice Cream Shop': 1,
#    'Juice Bar': 1,
#    'Hotel': 1,
#    'Bank': 1}},
#  {'postal_code': 'M3N',
#   'categories': {'Athletics & Sports': 1,
#    'Grocery Store': 1,
#    'Coffee Shop': 1,
#    'Gym / Fitness Center': 1}},
#  {'postal_code': 'M4N',
#   'categories': {'Swim School': 1,
#    'Park': 1,
#    'Bus Line': 1,
#    'Business Service': 1}},
#  {'postal_code': 'M5N',
#   'categories': {'Fast Food Restaurant': 1, 'Home Service': 1, 'Garden': 1}},
#  {'postal_code': 'M6N',
#   'categories': {'Bus Line': 1,
#    'Breakfast Spot': 1,
#    'Pizza Place': 1,
#    'Convenience Store': 1}},
#  {'postal_code': 'M9N',
#   'categories': {'Jewelry Store': 1, 'Convenience Store': 1}},
#  {'postal_code': 'M1P',
#   'categories': {'Indian Restaurant': 2,
#    'Chinese Restaurant': 1,
#    'Pet Store': 1,
#    'Light Rail Station': 1,
#    'Vietnamese Restaurant': 1}},
#  {'postal_code': 'M2P',
#   'categories': {'Flower Shop': 1,
#    'Park': 1,
#    'Construction & Landscaping': 1,
#    'Convenience Store': 1}},
#  {'postal_code': 'M4P',
#   'categories': {'Gym': 1,
#    'Food & Drink Shop': 1,
#    'Department Store': 1,
#    'Hotel': 1,
#    'Sandwich Place': 1,
#    'Breakfast Spot': 1,
#    'Park': 1,
#    'Pizza Place': 1}},
#  {'postal_code': 'M5P',
#   'categories': {'Sushi Restaurant': 1,
#    'Mexican Restaurant': 1,
#    'Trail': 1,
#    'Jewelry Store': 1}},
#  {'postal_code': 'M6P',
#   'categories': {'Café': 2,
#    'Mexican Restaurant': 2,
#    'Thai Restaurant': 2,
#    'Bakery': 2,
#    'Antique Shop': 1,
#    'Music Venue': 1,
#    'Park': 1,
#    'Bookstore': 1,
#    'Flea Market': 1,
#    'Bar': 1,
#    'Grocery Store': 1,
#    'Diner': 1,
#    'Fried Chicken Joint': 1,
#    'Gastropub': 1,
#    'Italian Restaurant': 1,
#    'Discount Store': 1,
#    'Cajun / Creole Restaurant': 1,
#    'Fast Food Restaurant': 1,
#    'Furniture / Home Store': 1,
#    'Speakeasy': 1,
#    'Arts & Crafts Store': 1}},
#  {'postal_code': 'M9P',
#   'categories': {'Pizza Place': 2,
#    'Chinese Restaurant': 1,
#    'Intersection': 1,
#    'Sandwich Place': 1,
#    'Discount Store': 1,
#    'Coffee Shop': 1}},
#  {'postal_code': 'M1R',
#   'categories': {'Middle Eastern Restaurant': 1,
#    'Sandwich Place': 1,
#    'Vietnamese Restaurant': 1,
#    'Bakery': 1,
#    'Auto Garage': 1}},
#  {'postal_code': 'M2R',
#   'categories': {'Coffee Shop': 1,
#    'Pharmacy': 1,
#    'Grocery Store': 1,
#    'Pizza Place': 1,
#    'Discount Store': 1}},
#  {'postal_code': 'M4R',
#   'categories': {'Coffee Shop': 2,
#    'Clothing Store': 2,
#    'Café': 1,
#    'Mexican Restaurant': 1,
#    'Gym / Fitness Center': 1,
#    'Spa': 1,
#    'Fast Food Restaurant': 1,
#    'Pet Store': 1,
#    'Sporting Goods Shop': 1,
#    'Yoga Studio': 1,
#    'Diner': 1,
#    'Chinese Restaurant': 1,
#    'Park': 1,
#    'Restaurant': 1,
#    'Salon / Barbershop': 1}},
#  {'postal_code': 'M5R',
#   'categories': {'Café': 3,
#    'Sandwich Place': 3,
#    'Coffee Shop': 2,
#    'Middle Eastern Restaurant': 1,
#    'Pharmacy': 1,
#    'Donut Shop': 1,
#    'Park': 1,
#    'Pizza Place': 1,
#    'Furniture / Home Store': 1,
#    'Liquor Store': 1,
#    'Flower Shop': 1,
#    'History Museum': 1,
#    'Indian Restaurant': 1,
#    'BBQ Joint': 1,
#    'Burger Joint': 1,
#    'Pub': 1}},
#  {'postal_code': 'M6R',
#   'categories': {'Gift Shop': 2,
#    'Breakfast Spot': 2,
#    'Movie Theater': 1,
#    'Dessert Shop': 1,
#    'Dog Run': 1,
#    'Coffee Shop': 1,
#    'Italian Restaurant': 1,
#    'Eastern European Restaurant': 1,
#    'Bar': 1,
#    'Bookstore': 1,
#    'Restaurant': 1,
#    'Cuban Restaurant': 1}},
#  {'postal_code': 'M7R',
#   'categories': {'Coffee Shop': 3,
#    'Hotel': 2,
#    'American Restaurant': 1,
#    'Burrito Place': 1,
#    'Mediterranean Restaurant': 1,
#    'Intersection': 1,
#    'Sandwich Place': 1,
#    'Fried Chicken Joint': 1}},
#  {'postal_code': 'M9R',
#   'categories': {'Mobile Phone Shop': 1,
#    'Sandwich Place': 1,
#    'Park': 1,
#    'Bus Line': 1}},
#  {'postal_code': 'M1S',
#   'categories': {'Latin American Restaurant': 1,
#    'Lounge': 1,
#    'Breakfast Spot': 1,
#    'Clothing Store': 1}},
#  {'postal_code': 'M4S',
#   'categories': {'Pizza Place': 4,
#    'Dessert Shop': 3,
#    'Sandwich Place': 3,
#    'Sushi Restaurant': 2,
#    'Italian Restaurant': 2,
#    'Café': 2,
#    'Coffee Shop': 2,
#    'Gym': 2,
#    'Greek Restaurant': 1,
#    'Gourmet Shop': 1,
#    'Brewery': 1,
#    'Gas Station': 1,
#    'Seafood Restaurant': 1,
#    'Discount Store': 1,
#    'Restaurant': 1,
#    'Pharmacy': 1,
#    'Indian Restaurant': 1,
#    'Diner': 1,
#    'Thai Restaurant': 1,
#    'Farmers Market': 1,
#    'Toy / Game Store': 1,
#    'Park': 1}},
#  {'postal_code': 'M5S',
#   'categories': {'Café': 5,
#    'Bakery': 2,
#    'Japanese Restaurant': 2,
#    'Bookstore': 2,
#    'Bar': 2,
#    'College Gym': 1,
#    'Dessert Shop': 1,
#    'Beer Bar': 1,
#    'French Restaurant': 1,
#    'Yoga Studio': 1,
#    'Bank': 1,
#    'Italian Restaurant': 1,
#    'Restaurant': 1,
#    'College Arts Building': 1,
#    'Theater': 1,
#    'Video Game Store': 1,
#    'Noodle House': 1,
#    'Sandwich Place': 1,
#    'Sushi Restaurant': 1,
#    'Comfort Food Restaurant': 1,
#    'Beer Store': 1,
#    'Pub': 1}},
#  {'postal_code': 'M6S',
#   'categories': {'Café': 3,
#    'Coffee Shop': 2,
#    'Italian Restaurant': 2,
#    'Diner': 2,
#    'Pizza Place': 2,
#    'Sushi Restaurant': 2,
#    'Grocery Store': 2,
#    'Pub': 2,
#    'Dessert Shop': 1,
#    'Arts & Crafts Store': 1,
#    'Bank': 1,
#    'Restaurant': 1,
#    'Bookstore': 1,
#    'Burrito Place': 1,
#    'Gourmet Shop': 1,
#    'Yoga Studio': 1,
#    'Latin American Restaurant': 1,
#    'Vegetarian / Vegan Restaurant': 1,
#    'Falafel Restaurant': 1,
#    'Sandwich Place': 1,
#    'Bar': 1,
#    'Electronics Store': 1,
#    'Indie Movie Theater': 1,
#    'Smoothie Shop': 1,
#    'Fish & Chips Shop': 1,
#    'French Restaurant': 1,
#    'Gym': 1}},
#  {'postal_code': 'M1T',
#   'categories': {'Pizza Place': 2,
#    'Fast Food Restaurant': 1,
#    'Intersection': 1,
#    'Convenience Store': 1,
#    'Pharmacy': 1,
#    'Italian Restaurant': 1,
#    'Chinese Restaurant': 1,
#    'Thai Restaurant': 1,
#    'Fried Chicken Joint': 1,
#    'Gas Station': 1,
#    'Noodle House': 1,
#    'Bank': 1}},
#  {'postal_code': 'M4T', 'categories': {'Restaurant': 1, 'Playground': 1}},
#  {'postal_code': 'M5T',
#   'categories': {'Café': 5,
#    'Coffee Shop': 4,
#    'Vegetarian / Vegan Restaurant': 4,
#    'Mexican Restaurant': 3,
#    'Vietnamese Restaurant': 3,
#    'Grocery Store': 2,
#    'Gaming Cafe': 2,
#    'Caribbean Restaurant': 2,
#    'Bar': 2,
#    'Wine Bar': 1,
#    'Pharmacy': 1,
#    'Pizza Place': 1,
#    'Beer Bar': 1,
#    'Doner Restaurant': 1,
#    'Burrito Place': 1,
#    'Organic Grocery': 1,
#    'Arts & Crafts Store': 1,
#    'Tea Room': 1,
#    'Dumpling Restaurant': 1,
#    'Belgian Restaurant': 1,
#    'Park': 1,
#    'Bakery': 1,
#    'Skating Rink': 1,
#    'Record Shop': 1,
#    'Farmers Market': 1,
#    'Italian Restaurant': 1,
#    'Gourmet Shop': 1,
#    'Poutine Place': 1,
#    'Smoothie Shop': 1,
#    'Food Court': 1,
#    'Fish Market': 1,
#    'Hospital': 1,
#    'Dessert Shop': 1,
#    'Cocktail Bar': 1,
#    'Bed & Breakfast': 1,
#    'Jazz Club': 1,
#    'Brewery': 1,
#    'Comfort Food Restaurant': 1,
#    'Japanese Restaurant': 1,
#    'Restaurant': 1,
#    'Breakfast Spot': 1,
#    'Filipino Restaurant': 1,
#    'Cheese Shop': 1}},
#  {'postal_code': 'M1V',
#   'categories': {'Park': 1, 'Intersection': 1, 'Playground': 1}},
#  {'postal_code': 'M4V',
#   'categories': {'Coffee Shop': 2,
#    'Light Rail Station': 2,
#    'American Restaurant': 1,
#    'Bagel Shop': 1,
#    'Sushi Restaurant': 1,
#    'Pizza Place': 1,
#    'Vietnamese Restaurant': 1,
#    'Liquor Store': 1,
#    'Pub': 1,
#    'Fried Chicken Joint': 1,
#    'Restaurant': 1,
#    'Bank': 1,
#    'Supermarket': 1}},
#  {'postal_code': 'M5V',
#   'categories': {'Airport Service': 3,
#    'Airport Terminal': 2,
#    'Airport Lounge': 2,
#    'Sculpture Garden': 1,
#    'Harbor / Marina': 1,
#    'Airport': 1,
#    'Coffee Shop': 1,
#    'Airport Food Court': 1,
#    'Plane': 1,
#    'Airport Gate': 1,
#    'Rental Car Location': 1,
#    'Boat or Ferry': 1}},
#  {'postal_code': 'M8V',
#   'categories': {'Café': 1,
#    'Liquor Store': 1,
#    'Pharmacy': 1,
#    'American Restaurant': 1,
#    'Fast Food Restaurant': 1,
#    'Mexican Restaurant': 1,
#    'Gym': 1,
#    'Fried Chicken Joint': 1,
#    'Bakery': 1,
#    'Restaurant': 1,
#    'Pizza Place': 1}},
#  {'postal_code': 'M9V',
#   'categories': {'Grocery Store': 2,
#    'Fast Food Restaurant': 1,
#    'Pharmacy': 1,
#    'Beer Store': 1,
#    'Sandwich Place': 1,
#    'Fried Chicken Joint': 1,
#    'Pizza Place': 1,
#    'Discount Store': 1}},
#  {'postal_code': 'M1W',
#   'categories': {'Coffee Shop': 2,
#    'Pharmacy': 1,
#    'Grocery Store': 1,
#    'Gym Pool': 1,
#    'Sandwich Place': 1,
#    'Pizza Place': 1,
#    'Discount Store': 1,
#    'Fast Food Restaurant': 1,
#    'Indian Restaurant': 1,
#    'Chinese Restaurant': 1,
#    'Breakfast Spot': 1,
#    'Bank': 1,
#    'Supermarket': 1}},
#  {'postal_code': 'M4W',
#   'categories': {'Park': 2, 'Playground': 1, 'Trail': 1}},
#  {'postal_code': 'M5W',
#   'categories': {'Coffee Shop': 10,
#    'Seafood Restaurant': 4,
#    'Beer Bar': 3,
#    'Restaurant': 3,
#    'Italian Restaurant': 3,
#    'Hotel': 3,
#    'Cocktail Bar': 3,
#    'Café': 3,
#    'Japanese Restaurant': 3,
#    'Creperie': 2,
#    'Breakfast Spot': 2,
#    'Park': 2,
#    'Art Gallery': 2,
#    'Farmers Market': 2,
#    'Cheese Shop': 2,
#    'Lounge': 2,
#    'Gym': 2,
#    'Bakery': 2,
#    'Irish Pub': 1,
#    'Comfort Food Restaurant': 1,
#    'French Restaurant': 1,
#    'Pharmacy': 1,
#    'Museum': 1,
#    'Soup Place': 1,
#    'Basketball Stadium': 1,
#    'Molecular Gastronomy Restaurant': 1,
#    'Grocery Store': 1,
#    'Sporting Goods Shop': 1,
#    'Fast Food Restaurant': 1,
#    'Eastern European Restaurant': 1,
#    'Clothing Store': 1,
#    'Poke Place': 1,
#    'Diner': 1,
#    'Bistro': 1,
#    'Bookstore': 1,
#    'Concert Hall': 1,
#    'Pizza Place': 1,
#    'Sushi Restaurant': 1,
#    'Fish Market': 1,
#    'Optical Shop': 1,
#    'Gourmet Shop': 1,
#    'Food Truck': 1,
#    'Cosmetics Shop': 1,
#    'Liquor Store': 1,
#    'Deli / Bodega': 1,
#    'Jazz Club': 1,
#    'American Restaurant': 1,
#    'Church': 1,
#    'Movie Theater': 1,
#    'Department Store': 1,
#    'Fountain': 1,
#    'Yoga Studio': 1,
#    'Sandwich Place': 1,
#    'Thai Restaurant': 1,
#    'Antique Shop': 1,
#    'Vegetarian / Vegan Restaurant': 1,
#    'Pub': 1,
#    'Tailor Shop': 1,
#    'Gastropub': 1,
#    'Juice Bar': 1,
#    'Bagel Shop': 1}},
#  {'postal_code': 'M8W',
#   'categories': {'Pizza Place': 2,
#    'Skating Rink': 1,
#    'Gym': 1,
#    'Pharmacy': 1,
#    'Coffee Shop': 1,
#    'Pub': 1}},
#  {'postal_code': 'M9W',
#   'categories': {'Bar': 1,
#    'Drugstore': 1,
#    'Rental Car Location': 1,
#    'Truck Stop': 1}},
#  {'postal_code': 'M1X', 'categories': {}},
#  {'postal_code': 'M4X',
#   'categories': {'Coffee Shop': 4,
#    'Bakery': 3,
#    'Market': 2,
#    'Restaurant': 2,
#    'Pizza Place': 2,
#    'Park': 2,
#    'Café': 2,
#    'Italian Restaurant': 2,
#    'Pub': 2,
#    'Pharmacy': 1,
#    'Playground': 1,
#    'Bank': 1,
#    'Grocery Store': 1,
#    'Chinese Restaurant': 1,
#    'Thai Restaurant': 1,
#    'Diner': 1,
#    'Indian Restaurant': 1,
#    'Farmers Market': 1,
#    'Pet Store': 1,
#    'Taiwanese Restaurant': 1,
#    'Deli / Bodega': 1,
#    'Convenience Store': 1,
#    'Snack Place': 1,
#    'Gastropub': 1,
#    'Sandwich Place': 1,
#    'Beer Store': 1,
#    'General Entertainment': 1,
#    'Liquor Store': 1,
#    'Caribbean Restaurant': 1,
#    'Japanese Restaurant': 1,
#    'Jewelry Store': 1,
#    'Gift Shop': 1,
#    'Butcher': 1}},
#  {'postal_code': 'M5X',
#   'categories': {'Coffee Shop': 11,
#    'Café': 7,
#    'Hotel': 6,
#    'Restaurant': 4,
#    'Japanese Restaurant': 4,
#    'Gym': 4,
#    'Asian Restaurant': 3,
#    'Deli / Bodega': 3,
#    'Salad Place': 3,
#    'Seafood Restaurant': 3,
#    'Steakhouse': 3,
#    'American Restaurant': 3,
#    'Pizza Place': 2,
#    'Gastropub': 2,
#    'Sushi Restaurant': 2,
#    'Thai Restaurant': 2,
#    'Bar': 2,
#    'Concert Hall': 2,
#    'Beer Bar': 2,
#    'Fast Food Restaurant': 1,
#    'Plaza': 1,
#    'Lounge': 1,
#    'New American Restaurant': 1,
#    'Salon / Barbershop': 1,
#    'Museum': 1,
#    'Speakeasy': 1,
#    'Colombian Restaurant': 1,
#    'Tea Room': 1,
#    'Bookstore': 1,
#    'Bakery': 1,
#    'Cocktail Bar': 1,
#    'Mediterranean Restaurant': 1,
#    'Greek Restaurant': 1,
#    'Italian Restaurant': 1,
#    'Gift Shop': 1,
#    'Food Court': 1,
#    'Theater': 1,
#    'General Travel': 1,
#    'Gym / Fitness Center': 1,
#    'Fried Chicken Joint': 1,
#    'Burger Joint': 1,
#    'Latin American Restaurant': 1,
#    'Sandwich Place': 1,
#    'Vegetarian / Vegan Restaurant': 1,
#    'Monument / Landmark': 1,
#    'Pub': 1,
#    'Train Station': 1,
#    'Gluten-free Restaurant': 1,
#    'Wine Bar': 1,
#    'Opera House': 1,
#    'Art Gallery': 1}},
#  {'postal_code': 'M8X',
#   'categories': {'Smoke Shop': 1, 'Pool': 1, 'River': 1}},
#  {'postal_code': 'M4Y',
#   'categories': {'Coffee Shop': 7,
#    'Sushi Restaurant': 5,
#    'Japanese Restaurant': 5,
#    'Gay Bar': 3,
#    'Restaurant': 3,
#    'Mediterranean Restaurant': 2,
#    'Fast Food Restaurant': 2,
#    'Pub': 2,
#    'Café': 2,
#    "Men's Store": 2,
#    'Yoga Studio': 2,
#    'Hotel': 2,
#    'Sake Bar': 1,
#    'Dessert Shop': 1,
#    'Smoke Shop': 1,
#    'Sculpture Garden': 1,
#    'Distribution Center': 1,
#    'Dance Studio': 1,
#    'Beer Bar': 1,
#    'Ice Cream Shop': 1,
#    'Mexican Restaurant': 1,
#    'Martial Arts School': 1,
#    'Clothing Store': 1,
#    'Dog Run': 1,
#    'Diner': 1,
#    'Adult Boutique': 1,
#    'Burrito Place': 1,
#    'Bookstore': 1,
#    'Theme Restaurant': 1,
#    'Gastropub': 1,
#    'Health & Beauty Service': 1,
#    'Creperie': 1,
#    'Strip Club': 1,
#    'Theater': 1,
#    'Food & Drink Shop': 1,
#    'Caribbean Restaurant': 1,
#    'Burger Joint': 1,
#    'Steakhouse': 1,
#    'American Restaurant': 1,
#    'Ethiopian Restaurant': 1,
#    'Pizza Place': 1,
#    'Ramen Restaurant': 1,
#    'Juice Bar': 1,
#    'Indian Restaurant': 1,
#    'Thai Restaurant': 1,
#    'Breakfast Spot': 1,
#    'Park': 1,
#    'Intersection': 1,
#    'Bubble Tea Shop': 1,
#    'Korean Restaurant': 1,
#    'Gym': 1,
#    'Grocery Store': 1,
#    'Salon / Barbershop': 1}},
#  {'postal_code': 'M7Y',
#   'categories': {'Garden Center': 1,
#    'Farmers Market': 1,
#    'Park': 1,
#    'Comic Shop': 1,
#    'Brewery': 1,
#    'Pizza Place': 1,
#    'Spa': 1,
#    'Fast Food Restaurant': 1,
#    'Light Rail Station': 1,
#    'Auto Workshop': 1,
#    'Garden': 1,
#    'Burrito Place': 1,
#    'Restaurant': 1,
#    'Skate Park': 1}},
#  {'postal_code': 'M8Y',
#   'categories': {'Baseball Field': 1, 'Business Service': 1}},
#  {'postal_code': 'M8Z',
#   'categories': {'Tanning Salon': 1,
#    'Convenience Store': 1,
#    'Grocery Store': 1,
#    'Gym': 1,
#    'Sandwich Place': 1,
#    'Discount Store': 1,
#    'Fast Food Restaurant': 1,
#    'Supplement Shop': 1,
#    'Kids Store': 1,
#    'Burrito Place': 1,
#    'Hardware Store': 1,
#    'Burger Joint': 1,
#    'Bakery': 1,
#    'Wings Joint': 1}}]
